# %% [markdown]
# ## Introduction

# %% [markdown]
# In this notebook, I plan to find the best neighborhood in Pittsburgh, PA to have a kid in. The particular dataset that I chose to focus on is the best school environment/neighborhood to enroll a kid in.

# %% [markdown]
# ## Metric

# %% [markdown]
# The metric that I decided to focus on is the density of school for choice. Within this metric, I plan to research the best public school to enroll a kid in around the Pittsburgh area. Out of all the schools, I would find the top neighborhood location for schools for a kid to attend. The dataset that I will be using to prove the density of school for choice is listed below:
#
# https://data.wprdc.org/dataset/pittsburgh-public-school-locations
# https://data.wprdc.org/dataset/pittsburgh-public-schools-enrollment/resource/7b0660d1-c812-496d-ab0a-8560902e9e70

# %% [markdown]
# ## The Best Neighborhood

# %%
import pandas as pd

chip = pd.read_csv("https://data.wprdc.org/dataset/46fb3ca4-e844-4b42-b034-e87291d34699/resource/06664b02-c673-49d5-8a70-d3cd1c18ac8d/download/pps_schoolsapr2019publish.csv")
ran = pd.read_csv("https://data.wprdc.org/dataset/27b6eef7-8825-4cc4-8b48-52c17ac80d37/resource/7b0660d1-c812-496d-ab0a-8560902e9e70/download/neighborhood_school_enrollment.csv")
chip.head()
ran.head()
#ran.plot.bar()
query_mask = ran['enrolled_students'] > 150
blah = ran[query_mask]
blah.plot.bar(x = "neighborhood" , rot = 90)

# %%
import pandas as pd
from matplotlib import pyplot as plt

sorted = ran.sort_values(by = ['enrolled_students'])

sorted.head(5)
lowest = sorted.head(5)

sorted.tail(5)
highest = sorted.tail(5)

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (30,10))


ax1.bar(blah["neighborhood"],blah["enrolled_students"], color = ["violet", "pink", "blue", "silver"])
ax1.tick_params('x', labelrotation = 90)
ax1.title.set_text('Neighborhoods')


ax2.bar(lowest["neighborhood"],lowest["enrolled_students"], color = ["green", "brown", "red", "black", "grey"])
ax2.tick_params('x', labelrotation = 90)
ax2.title.set_text('LOWEST 5')


ax3.bar(highest["neighborhood"],highest["enrolled_students"], color = ["yellow", "orange", "pink", "red", "purple"])
ax3.tick_params('x', labelrotation = 90)
ax3.title.set_text('TOP 5')

# %% [markdown]
# # So what is the overall best neighborhood to have a kid in?

# %% [markdown]
# I think the best neighborhood to enroll a kid is in Brookline, PA. I believe that this will be the best school for a kid to enroll because it has the most enrolled students in this particular neighborhood. I believe that since this neighborhood is surrounded by more kids, new enrolled kids will be able to succeed together because their neighborhood school has the most enrolled students. Brookline, PA has almost 350+ students enrolled into the neighborhood school. Compared to the other neighborhoods, there is no other neighborhood who has as much students enrolled into the school. It will allow several kids to develop a friendship within the neighborhood, and also kids that are around their age.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The data driven determination of the best neighborhood is the same as my personal favorite neighborhood because it has the most enrolled students arounf the neighborhood and it is known as one the most beautiful branches of the Carneige Library of Pittsburgh. To my beliefs, the pros to having a library branch in your neighborhood is the best thing a kid can ask for. According to data statistics, it appears that a kid is more likely to have fun in this neighborhood compared to any other neighborhood since they're is more kids involved within the community. Overall, I think Brookline, PA is the best neighborhood to have a kid in :)
